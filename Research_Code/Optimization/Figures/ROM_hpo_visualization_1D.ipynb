# %% [markdown]
# # Visualizing the Results of the ROM Hyperparameter Optimization
# - This notebook should be for two things: actually doing the HPO (figuring out increase in learning with different param combinations, and timing them, etc.) as well as visualizing their outputs
# - But I'm lazy and so am outsourcing that first part to Codex.

# %% [markdown]
# ## Visualizing Best Runs

# %%
# Best early ROM test (by final error): ROM_M_R_HPO/ROM_short_training_param_sweep_32_m-4__r-10
# Best later ROM test (by final error): ROM_longer_learning/ROM_m4_r10_longer_fu_tuning_0_020m_more_full_stage_base_eta
# Best 1 hour later ROM test (by final error): ROM_longer_learning/ROM_m4_r10_longer_fu_tuning_6_060m_more_full_stage_base_eta
# Best m=10 stability (by final error): ROM_1D_m=10_stability_07_09_2026/ROM_m10_stability_fu_learning_62_r10_high_obs_late_eta_5e-4_to_1e-5_obs_2_5_10_25_50_budget30m
# Best logical extension of early ROM best (by final error): ROM_m4_r10_logical_extension/ROM_m4_r10_longer_fu_tuning_logical_extension_5_006_extend_60k_eta1e-4_obs50

dir_path_name = "ROM_m4_r10_logical_extension/ROM_m4_r10_longer_fu_tuning_logical_extension_5_006_extend_60k_eta1e-4_obs50"
# Out:
# "ROM_m4_r10_logical_extension/ROM_m4_r10_longer_fu_tuning_logical_extension_5_006_extend_60k_eta1e-4_obs50"

# %%
include(joinpath(@__DIR__, "..", "..", "src", "Visualizations", "optimization_metadata_visualizations.jl"))
include(joinpath(@__DIR__, "..", "..", "src", "Visualizations", "optimization_visualizations.jl"))
run_dir = joinpath(@__DIR__, "..", "Data", dir_path_name)
# Out:
# "/Users/milesgantcher/Library/CloudStorage/OneDrive-RiceUniversity/Documents/VSCode_Projects/Brookhaven/Research_Code/Optimization/Figures/../Data/ROM_m4_r10_logical_extension/ROM_m4_r10_longer_fu_tuning_logical_extension_5_006_extend_60k_eta1e-4_obs50"

# %%
visualize_ROM_metadata(run_dir)
# Out:
# saved_at = "2026-07-09T11:12:39"
# julia_version = v"1.12.6"
# N = 256
# ε2 = 0.01
# k = 1.0
# Δx = 0.0038910505836575876
# tspan = (0.0, 2.0)
# N_obs = 99
# reference_steps = 5282
# r = 10
# m = 4
# h = 8
# activation = "tanh"
# seed = 1
# reference_algorithm = "Euler"
# ode_algorithm = "TRBDF2{AutoFiniteDiff{Val{:forward}, Val{:forward}, Val{:hcentral}, Nothing, Nothing, Int64}, Nothing, OrdinaryDiffEqNonlinearSolve.NLNewton{Rational{Int64}, Rational{Int64}, Rational{Int64}, Nothing}, typeof(OrdinaryDiffEqCore.trivial_limiter!), Nothing}(nothing, OrdinaryDiffEqNonlinearSolve.NLNewton{Rational{Int64}, Rational{Int64}, Rational{Int64}, Nothing}(1//100, 10, 1//5, 1//5, false, true, nothing), true, OrdinaryDiffEqCore.Predictor.Linear, OrdinaryDiffEqCore.trivial_limiter!, AutoFiniteDiff(), nothing)"
# sensitivity_algorithm = "GaussAdjoint{0, true, Val{:central}, SciMLSensitivity.MooncakeVJP, Val{true}}(SciMLSensitivity.MooncakeVJP(), false, Val{true}())"
# optimizer = "Adam variable-window staged"
# η = [0.01, 0.003, 0.001, 0.0001]
# N_iter = 66573
# η_schedule = [0.01, 0.003, 0.001, 0.0001]
# N_iter_schedule = [2016, 2208, 2349, 60000]
# β = (0.9, 0.99)
# window_T = [0.05, 0.5, 2.0, 2.0]
# window_N_obs = [2, 5, 10, 50]
# window_start_policy = SubString{String}["random", "random", "random", "random"]
# batch_size = [1, 1, 1, 1]
# window_T_schedule = [0.05, 0.5, 2.0, 2.0]
# window_N_obs_schedule = [2, 5, 10, 50]
# window_start_policy_schedule = SubString{String}["random", "random", "random", "random"]
# batch_size_schedule = [1, 1, 1, 1]
# loss_normalization = "mean"
# window_seed = 1
# validation_N_obs = 100
# warmup = true
# save_frequency = 100
# print_frequency = 500
# final_training_loss = 2.6709139885425684e-8
# final_full_trajectory_loss = 2.7794388692859192e-8
# initial_loss = 0.000183146383037337
# final_loss = 2.7794388692859192e-8
# parameter_snapshots = 667
#
# Derived serialized metadata:
# serialized_file = "rom_data.jls"
# dimension = 1
# boundary_condition = "homogeneous_dirichlet"
# grid_N = 256
# state_length = 256
# model_type = "nn"
# polynomial_degree = nothing

# %%
visualize_ROM_trajectories(run_dir; max_frames=120, fps=15)
# Out:
# ┌ Info: Saved animation to /Users/milesgantcher/Library/CloudStorage/OneDrive-RiceUniversity/Documents/VSCode_Projects/Brookhaven/Research_Code/Optimization/Data/ROM_m4_r10_logical_extension/ROM_m4_r10_longer_fu_tuning_logical_extension_5_006_extend_60k_eta1e-4_obs50/visualizations/overlaid_rom_trajectory.gif
# └ @ Plots /Users/milesgantcher/.julia/packages/Plots/GIume/src/animation.jl:156
# <img src="data:image/gif;base64,..." style="max-width: 100%;">

# %%
visualize_ROM_learned_function(run_dir)

# %%
visualize_ROM_modes(run_dir)

# %%
visualize_ROM_loss(run_dir)
