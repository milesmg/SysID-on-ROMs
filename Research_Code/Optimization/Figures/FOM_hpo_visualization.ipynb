# %% [markdown]
# # Visualizing the Results of the FOM Hyperparameter Optimization
# - This notebook should be for two things: actually doing the HPO (figuring out increase in learning with different param combinations, and timing them, etc.) as well as visualizing their outputs
# - But I'm lazy and so am outsourcing that first part to Codex.

# %% [markdown]
# ## Visualizing Best Runs

# %%
include(joinpath(@__DIR__, "..", "..", "src", "Visualizations", "optimization_metadata_visualizations.jl"))
include(joinpath(@__DIR__, "..", "..", "src", "Visualizations", "optimization_visualizations.jl"))
run_dir = joinpath(@__DIR__, "..", "Data", "FOM_HPO/FOM_true_hpo_mooncake_90_25_026_fast10m_w_0p05_0p5_2p0__obs_2_5_10__eta_0.01_0.003_0.001__b_1_1_1")
# Out:
# "/Users/milesgantcher/Library/CloudStorage/OneDrive-RiceUniversity/Documents/VSCode_Projects/Brookhaven/Research_Code/Optimization/Figures/../Data/FOM_HPO/FOM_true_hpo_mooncake_90_25_026_fast10m_w_0p05_0p5_2p0__obs_2_5_10__eta_0.01_0.003_0.001__b_1_1_1"

# %%
visualize_FOM_metadata(run_dir)
# Out:
# N = 256
# L = 1.0
# ε2 = 0.01
# Δx = 0.0038910505836575876
# ...

# %% [markdown]
# Parameter_snapshots = 2 is very low! This is because save_frequency was way too high.

# %%
visualize_FOM_trajectories(run_dir; max_frames=120, fps=15)
# Out:
# ┌ Info: Saved animation to /Users/milesgantcher/Library/CloudStorage/OneDrive-RiceUniversity/Documents/VSCode_Projects/Brookhaven/Research_Code/Optimization/Data/FOM_HPO/FOM_true_hpo_mooncake_90_25_026_fast10m_w_0p05_0p5_2p0__obs_2_5_10__eta_0.01_0.003_0.001__b_1_1_1/visualizations/overlaid_fom_trajectory.gif
# └ @ Plots /Users/milesgantcher/.julia/packages/Plots/GIume/src/animation.jl:156
# <img src="data:image/gif;base64,..." style="max-width: 100%;">

# %%
visualize_FOM_learned_function(run_dir)

# %%
visualize_FOM_loss(run_dir)
