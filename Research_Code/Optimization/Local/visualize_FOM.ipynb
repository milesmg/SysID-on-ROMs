# %% [markdown]
# ### FOM Optimization Visualization
#
# Set `run_dir` to a saved FOM directory under `Data`, then run whichever visualization cells you need.

# %%
### ADJUSTED: Load metadata-only helpers before heavy plotting and solver packages.
# ### ADJUSTED: Load visualization helpers from Research_Code/src.
include(joinpath(@__DIR__, "..", "..", "src", "Visualizations", "optimization_metadata_visualizations.jl"))
# Out:
# visualize_FOM_metadata

# %%
### ADJUSTED: Point this to the saved FOM Data directory you want to visualize.
# ### ADJUSTED: Resolve saved runs from Optimization/Data after moving this notebook.
run_dir = joinpath(@__DIR__, "..", "Data", "Local_FOM_trainings/FOM_AC_training_05_06_25_2026_2400_iterates_learn_rate_schedule_500_5e-3_800_1e-3_1100_1e-4")
# Out:
# "/Users/milesgantcher/Library/CloudStorage/OneDrive-RiceUniversity/Documents/VSCode_Projects/Brookhaven/Research_Code/Optimization/Local/../Data/Local_FOM_trainings/FOM_AC_training_05_06_25_2026_2400_iterates_learn_rate_schedule_500_5e-3_800_1e-3_1100_1e-4"

# %%
### ADJUSTED: Print saved FOM metadata as its own visualization step.
visualize_FOM_metadata(run_dir)
# Out:
# N = 256
# L = 1.0
# ε2 = 0.01
# Δx = 0.0038910505836575876
# ...

# %%
### ADJUSTED: Load full visualization helpers only after the lightweight metadata cell.
# ### ADJUSTED: Load visualization helpers from Research_Code/src.
include(joinpath(@__DIR__, "..", "..", "src", "Visualizations", "optimization_visualizations.jl"))
# Out:
# visualize_FOM

# %%
### ADJUSTED: Solve and display overlaid true/learned FOM trajectory GIF as its own step.
visualize_FOM_trajectories(run_dir; max_frames=120, fps=15)
# Out:
# ┌ Info: Saved animation to /Users/milesgantcher/Library/CloudStorage/OneDrive-RiceUniversity/Documents/VSCode_Projects/Brookhaven/Research_Code/Optimization/Data/FOM_AC_training_05_06_25_2026_2400_iterates_learn_rate_schedule_500_5e-3_800_1e-3_1100_1e-4/visualizations/overlaid_fom_trajectory.gif
# └ @ Plots /Users/milesgantcher/.julia/packages/Plots/GIume/src/animation.jl:156
# <img src="data:image/gif;base64,..." style="max-width: 100%;">

# %%
### ADJUSTED: Report FOM mode availability as its own step.
visualize_FOM_modes(run_dir)
# Out:
# FOM runs do not save POD/DEIM spatial or function modes.

# %%
### ADJUSTED: Plot learned versus true FOM nonlinearity as its own step.
visualize_FOM_learned_function(run_dir)

# %%
### ADJUSTED: Plot FOM loss history as its own step.
visualize_FOM_loss(run_dir)
